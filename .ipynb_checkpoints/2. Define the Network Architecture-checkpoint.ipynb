# %% [markdown]
# <a href="https://colab.research.google.com/github/pradhapmoorthi/P1_Facial_Keypoints/blob/master/.ipynb_checkpoints/2.%20Define%20the%20Network%20Architecture-checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Define the Convolutional Neural Network
#
# After you've looked at the data you're working with and, in this case, know the shapes of the images and of the keypoints, you are ready to define a convolutional neural network that can *learn* from this data.
#
# In this notebook and in `models.py`, you will:
# 1. Define a CNN with images as input and keypoints as output
# 2. Construct the transformed FaceKeypointsDataset, just as before
# 3. Train the CNN on the training data, tracking loss
# 4. See how the trained model performs on test data
# 5. If necessary, modify the CNN structure and model hyperparameters, so that it performs *well* **\***
#
# **\*** What does *well* mean?
#
# "Well" means that the model's loss decreases during training **and**, when applied to test image data, the model produces keypoints that closely match the true keypoints of each face. And you'll see examples of this later in the notebook.
#
# ---

# %% [markdown]
# ## CNN Architecture
#
# Recall that CNN's are defined by a few types of layers:
# * Convolutional layers
# * Maxpooling layers
# * Fully-connected layers
#
# You are required to use the above layers and encouraged to add multiple convolutional layers and things like dropout layers that may prevent overfitting. You are also encouraged to look at literature on keypoint detection, such as [this paper](https://arxiv.org/pdf/1710.00977.pdf), to help you determine the structure of your network.
#
#
# ### TODO: Define your model in the provided file `models.py` file
#
# This file is mostly empty but contains the expected name and some TODO's for creating your model.
#
# ---

# %% [markdown]
# ## PyTorch Neural Nets
#
# To define a neural network in PyTorch, you define the layers of a model in the function `__init__` and define the feedforward behavior of a network that employs those initialized layers in the function `forward`, which takes in an input image tensor, `x`. The structure of this Net class is shown below and left for you to fill in.
#
# Note: During training, PyTorch will be able to perform backpropagation by keeping track of the network's feedforward behavior and using autograd to calculate the update to the weights in the network.
#
# #### Define the Layers in ` __init__`
# As a reminder, a conv/pool layer may be defined like this (in `__init__`):
# ```
# # 1 input image channel (for grayscale images), 32 output channels/feature maps, 3x3 square convolution kernel
# self.conv1 = nn.Conv2d(1, 32, 3)
#
# # maxpool that uses a square window of kernel_size=2, stride=2
# self.pool = nn.MaxPool2d(2, 2)
# ```
#
# #### Refer to Layers in `forward`
# Then referred to in the `forward` function like this, in which the conv1 layer has a ReLu activation applied to it before maxpooling is applied:
# ```
# x = self.pool(F.relu(self.conv1(x)))
# ```
#
# Best practice is to place any layers whose weights will change during the training process in `__init__` and refer to them in the `forward` function; any layers or functions that always behave in the same way, such as a pre-defined activation function, should appear *only* in the `forward` function.

# %% [markdown]
# #### Why models.py
#
# You are tasked with defining the network in the `models.py` file so that any models you define can be saved and loaded by name in different notebooks in this project directory. For example, by defining a CNN class called `Net` in `models.py`, you can then create that same architecture in this and other notebooks by simply importing the class and instantiating a model:
# ```
#     from models import Net
#     net = Net()
# ```

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
get_ipython().system('wget https://raw.githubusercontent.com/pradhapmoorthi/P1_Facial_Keypoints/master/models.py')
# Out:
# --2025-12-27 19:40:18--  https://raw.githubusercontent.com/pradhapmoorthi/P1_Facial_Keypoints/master/models.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2891 (2.8K) [text/plain]
# Saving to: ‘models.py.2’
#
# models.py.2         100%[===================>]   2.82K  --.-KB/s    in 0s
#
# 2025-12-27 19:40:18 (39.9 MB/s) - ‘models.py.2’ saved [2891/2891]

# %%
import wandb

# Define a dictionary for experiment configuration
wandb_config_dict = {
    'model_choice': 'Net', # Placeholder for the model to be used
    'learning_rate': 0.001,
    'epochs': 10,
    'batch_size': 10,
    'optimizer': 'Adam',
    'loss_function': 'MSELoss'
}

# Initialize Weights & Biases
wandb.init(
    project='facial_keypoint_detection',
    config=wandb_config_dict
)

# Access the configuration parameters through wandb.config
print("WandB initialized with config:")
for key, value in wandb.config.items():
    print(f"  {key}: {value}")
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">mild-firebrand-23</strong> at: <a href='https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection/runs/e681n74d' target="_blank">https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection/runs/e681n74d</a><br> View project at: <a href='https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection' target="_blank">https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251227_193921-e681n74d/logs</code>
# Tracking run with wandb version 0.23.1
# Run data is saved locally in <code>/content/wandb/run-20251227_193954-1hs835ju</code>
# Syncing run <strong><a href='https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection/runs/1hs835ju' target="_blank">trim-wind-24</a></strong> to <a href='https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection' target="_blank">https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection</a>
#  View run at <a href='https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection/runs/1hs835ju' target="_blank">https://wandb.ai/moorthi-pradhap-tsd/facial_keypoint_detection/runs/1hs835ju</a>
# WandB initialized with config:
#   model_choice: Net
#   learning_rate: 0.001
#   epochs: 10
#   batch_size: 10
#   optimizer: Adam
#   loss_function: MSELoss

# %%
# import the usual resources
import matplotlib.pyplot as plt
import numpy as np

# watch for any changes in model.py, if it changes, re-load it automatically
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Transform the dataset
#
# To prepare for training, create a transformed dataset of images and keypoints.
#
# ### TODO: Define a data transform
#
# In PyTorch, a convolutional neural network expects a torch image of a consistent size as input. For efficient training, and so your model's loss does not blow up during training, it is also suggested that you normalize the input images and keypoints. The necessary transforms have been defined in `data_load.py` and you **do not** need to modify these; take a look at this file (you'll see the same transforms that were defined and applied in Notebook 1).
#
# To define the data transform below, use a [composition](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html#compose-transforms) of:
# 1. Rescaling and/or cropping the data, such that you are left with a square image (the suggested size is 224x224px)
# 2. Normalizing the images and keypoints; turning each RGB image into a grayscale image with a color range of [0, 1] and transforming the given keypoints into a range of [-1, 1]
# 3. Turning these images and keypoints into Tensors
#
# These transformations have been defined in `data_load.py`, but it's up to you to call them and create a `data_transform` below. **This transform will be applied to the training data and, later, the test data**. It will change how you go about displaying these images and keypoints, but these steps are essential for efficient training.
#
# As a note, should you want to perform data augmentation (which is optional in this project), and randomly rotate or shift these images, a square image size will be useful; rotating a 224x224 image by 90 degrees will result in the same shape of output.

# %%
get_ipython().system('wget https://raw.githubusercontent.com/pradhapmoorthi/P1_Facial_Keypoints/master/data_load.py')
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# the dataset we created in Notebook 1 is copied in the helper file `data_load.py`
from data_load import FacialKeypointsDataset
# the transforms we defined in Notebook 1 are in the helper file `data_load.py`
from data_load import Rescale, RandomCrop, Normalize, ToTensor


## TODO: define the data_transform using transforms.Compose([all tx's, . , .])
# order matters! i.e. rescaling should come before a smaller crop
data_transform = transforms.Compose([Rescale(250),
                                     RandomCrop(224),
                                     Normalize(),
                                     ToTensor()])

# testing that you've defined a transform
assert(data_transform is not None), 'Define a data_transform'
# Out:
# --2025-12-27 15:30:27--  https://raw.githubusercontent.com/pradhapmoorthi/P1_Facial_Keypoints/master/data_load.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4835 (4.7K) [text/plain]
# Saving to: ‘data_load.py’
#
# data_load.py        100%[===================>]   4.72K  --.-KB/s    in 0s
#
# 2025-12-27 15:30:28 (69.9 MB/s) - ‘data_load.py’ saved [4835/4835]

# %%
# First, create the 'data' directory if it doesn't exist
get_ipython().system('mkdir -p data')

# Download the entire P1_Facial_Keypoints repository as a zip file
get_ipython().system('wget https://github.com/pradhapmoorthi/P1_Facial_Keypoints/archive/master.zip -O P1_Facial_Keypoints-master.zip')

# Unzip the downloaded file
get_ipython().system('unzip P1_Facial_Keypoints-master.zip')

# Move the training and test image directories to the 'data' folder
get_ipython().system('mv P1_Facial_Keypoints-master/data/training data/')
get_ipython().system('mv P1_Facial_Keypoints-master/data/test data/')

# --- Diagnostic Step: List contents to check if images are there ---
print("Contents of data/training/")
get_ipython().system('ls -F data/training/')
print("Contents of data/test/")
get_ipython().system('ls -F data/test/')
# --- End Diagnostic Step ---

# Clean up the downloaded zip and extracted folder (optional)
get_ipython().system('rm P1_Facial_Keypoints-master.zip')
get_ipython().system('rm -r P1_Facial_Keypoints-master')

# Download the training keypoints CSV file (if not already present or overwritten)
get_ipython().system('wget -P data/ https://raw.githubusercontent.com/pradhapmoorthi/P1_Facial_Keypoints/master/data/training_frames_keypoints.csv')
# Download the testing keypoints CSV file (if not already present or overwritten)
get_ipython().system('wget -P data/ https://raw.githubusercontent.com/pradhapmoorthi/P1_Facial_Keypoints/master/data/test_frames_keypoints.csv')

# create the transformed dataset
transformed_dataset = FacialKeypointsDataset(csv_file='data/training_frames_keypoints.csv',
                                             root_dir='data/training/',
                                             transform=data_transform)


print('Number of images: ', len(transformed_dataset))

# iterate through the transformed dataset and print some stats about the first few samples
for i in range(4):
    sample = transformed_dataset[i]
    print(i, sample['image'].size(), sample['keypoints'].size())
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Caliendo_32.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Caliendo_40.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Caliendo_41.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Caliendo_42.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Caliendo_50.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Frank_Caliendo_51.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Caliendo_52.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Frank_Keating_30.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Frank_Keating_31.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Keating_32.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Keating_40.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Keating_41.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Keating_42.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Keating_50.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Keating_51.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Keating_52.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Frank_Solich_10.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Frank_Solich_11.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Frank_Solich_12.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Solich_20.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Solich_21.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Solich_22.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Solich_30.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Solich_31.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Frank_Solich_32.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Franz_Fischler_00.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Franz_Fischler_01.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Franz_Fischler_02.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Franz_Fischler_30.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Franz_Fischler_31.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Franz_Fischler_32.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Franz_Fischler_40.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Franz_Fischler_41.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Franz_Fischler_42.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Franz_Fischler_50.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Franz_Fischler_51.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Franz_Fischler_52.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/GL_Peiris_00.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/GL_Peiris_01.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/GL_Peiris_02.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/GL_Peiris_10.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/GL_Peiris_11.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/GL_Peiris_12.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/GL_Peiris_30.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/GL_Peiris_31.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/GL_Peiris_32.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_00.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_01.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_02.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_10.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_11.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_12.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_20.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_21.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_22.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_50.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_51.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gabi_Zimmer_52.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Bettman_10.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Bettman_11.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Bettman_12.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Bettman_30.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Bettman_31.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Bettman_32.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Bettman_40.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Bettman_41.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Bettman_42.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Coleman_30.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Coleman_31.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Coleman_32.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Coleman_40.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Coleman_41.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Coleman_42.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Gary_Coleman_50.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Coleman_51.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Gary_Coleman_52.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Condit_00.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Condit_01.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Condit_02.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Condit_10.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Condit_11.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gary_Condit_12.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Gary_Condit_30.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Gary_Condit_31.jpg
#   inflating: P1_Facial_Keypoints-master/data/training/Gary_Condit_32.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gene_Hackman_20.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gene_Hackman_21.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gene_Hackman_22.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gene_Hackman_30.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gene_Hackman_31.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gene_Hackman_32.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gene_Hackman_40.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gene_Hackman_41.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Gene_Hackman_42.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Geoffrey_Rush_00.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Geoffrey_Rush_01.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Geoffrey_Rush_02.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Geoffrey_Rush_10.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Geoffrey_Rush_11.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Geoffrey_Rush_12.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/Geoffrey_Rush_20.jpg
#  extracting: P1_Facial_Keypoints-master/data/training/
# James_McPherson_01.jpg		  Yang_Jianli_31.jpg
# James_McPherson_10.jpg		  Yuri_Fedotov_20.jpg
# James_McPherson_11.jpg		  Yuri_Fedotov_21.jpg
# James_McPherson_20.jpg		  Yuri_Fedotov_30.jpg
# James_McPherson_21.jpg		  Yuri_Fedotov_31.jpg
# James_Wolfensohn_00.jpg		  Yuri_Fedotov_40.jpg
# James_Wolfensohn_01.jpg		  Yuri_Fedotov_41.jpg
# James_Wolfensohn_20.jpg		  Zhang_Ziyi_10.jpg
# James_Wolfensohn_21.jpg		  Zhang_Ziyi_11.jpg
# James_Wolfensohn_30.jpg		  Zhang_Ziyi_20.jpg
# James_Wolfensohn_31.jpg		  Zhang_Ziyi_21.jpg
# James_Wolfensohn_50.jpg		  Zhang_Ziyi_40.jpg
# James_Wolfensohn_51.jpg		  Zhang_Ziyi_41.jpg
# Jane_Krakowski_00.jpg		  Zhong_Nanshan_00.jpg
# Jane_Krakowski_01.jpg		  Zhong_Nanshan_01.jpg
# Jane_Krakowski_10.jpg		  Zhong_Nanshan_10.jpg
# Jane_Krakowski_11.jpg		  Zhong_Nanshan_11.jpg
# Jane_Krakowski_40.jpg		  Zhong_Nanshan_50.jpg
# Jane_Krakowski_41.jpg		  Zhong_Nanshan_51.jpg
# --2025-12-27 15:30:50--  https://raw.githubusercontent.com/pradhapmoorthi/P1_Facial_Keypoints/master/data/training_frames_keypoints.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2653447 (2.5M) [text/plain]
# Saving to: ‘data/training_frames_keypoints.csv’
#
# training_frames_key 100%[===================>]   2.53M  --.-KB/s    in 0.03s
#
# 2025-12-27 15:30:50 (99.0 MB/s) - ‘data/training_frames_keypoints.csv’ saved [2653447/2653447]
#
# --2025-12-27 15:30:50--  https://raw.githubusercontent.com/pradhapmoorthi/P1_Facial_Keypoints/master/data/test_frames_keypoints.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 590606 (577K) [text/plain]
# Saving to: ‘data/test_frames_keypoints.csv’
#
# test_frames_keypoin 100%[===================>] 576.76K  --.-KB/s    in 0.01s
#
# 2025-12-27 15:30:50 (42.8 MB/s) - ‘data/test_frames_keypoints.csv’ saved [590606/590606]
#
# Number of images:  3462
# 0 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 1 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 2 torch.Size([1, 224, 224]) torch.Size([68, 2])
# 3 torch.Size([1, 224, 224]) torch.Size([68, 2])

# %% [markdown]
# ## Batching and loading data
#
# Next, having defined the transformed dataset, we can use PyTorch's DataLoader class to load the training data in batches of whatever size as well as to shuffle the data for training the model. You can read more about the parameters of the DataLoader, in [this documentation](http://pytorch.org/docs/master/data.html).
#
# #### Batch size
# Decide on a good batch size for training your model. Try both small and large batch sizes and note how the loss decreases as the model trains.
#
# **Note for Windows users**: Please change the `num_workers` to 0 or you may face some issues with your DataLoader failing.

# %%
# load training data in batches
batch_size = 10

train_loader = DataLoader(transformed_dataset,
                          batch_size=batch_size,
                          shuffle=True,
                          num_workers=0)

# %% [markdown]
# ## Before training
#
# Take a look at how this model performs before it trains. You should see that the keypoints it predicts start off in one spot and don't match the keypoints on a face at all! It's interesting to visualize this behavior so that you can compare it to the model after training and see how the model has improved.
#
# #### Load in the test dataset
#
# The test dataset is one that this model has *not* seen before, meaning it has not trained with these images. We'll load in this test data and before and after training, see how your model performs on this set!
#
# To visualize this test data, we have to go through some un-transformation steps to turn our images into python images from tensors and to turn our keypoints back into a recognizable range.

# %%
# load in the test data, using the dataset class
# AND apply the data_transform you defined above

# create the test dataset
test_dataset = FacialKeypointsDataset(csv_file='data/test_frames_keypoints.csv',
                                             root_dir='data/test/',
                                             transform=data_transform)

# %%
# load test data in batches
batch_size = 10

test_loader = DataLoader(test_dataset,
                          batch_size=batch_size,
                          shuffle=True,
                          num_workers=0)

# %% [markdown]
# ## Apply the model on a test sample
#
# To test the model on a test sample of data, you have to follow these steps:
# 1. Extract the image and ground truth keypoints from a sample
# 2. Make sure the image is a FloatTensor, which the model expects.
# 3. Forward pass the image through the net to get the predicted, output keypoints.
#
# This function test how the network performs on the first batch of test data. It returns the images, the transformed images, the predicted keypoints (produced by the model), and the ground truth keypoints.

# %%
# test the model on a batch of test images

def net_sample_output():

    # iterate through the test dataset
    for i, sample in enumerate(test_loader):

        # get sample data: images and ground truth keypoints
        images = sample['image']
        key_pts = sample['keypoints']

        # convert images to FloatTensors
        images = images.type(torch.FloatTensor)

        # forward pass to get net output
        output_pts = net(images)

        # reshape to batch_size x 68 x 2 pts
        output_pts = output_pts.view(output_pts.size()[0], 68, -1)

        # break after first image is tested
        if i == 0:
            return images, output_pts, key_pts

# %% [markdown]
# #### Debugging tips
#
# If you get a size or dimension error here, make sure that your network outputs the expected number of keypoints! Or if you get a Tensor type error, look into changing the above code that casts the data into float types: `images = images.type(torch.FloatTensor)`.

# %%
# call the above function
# returns: test images, test predicted keypoints, test ground truth keypoints
test_images, test_outputs, gt_pts = net_sample_output()

# print out the dimensions of the data to see if they make sense
print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %% [markdown]
# ## Visualize the predicted keypoints
#
# Once we've had the model produce some predicted output keypoints, we can visualize these points in a way that's similar to how we've displayed this data before, only this time, we have to "un-transform" the image/keypoint data to display it.
#
# Note that I've defined a *new* function, `show_all_keypoints` that displays a grayscale image, its predicted keypoints and its ground truth keypoints (if provided).

# %%
def show_all_keypoints(image, predicted_key_pts, gt_pts=None):
    """Show image with predicted keypoints"""
    # image is grayscale
    plt.imshow(image, cmap='gray')
    plt.scatter(predicted_key_pts[:, 0], predicted_key_pts[:, 1], s=20, marker='.', c='m')
    # plot ground truth points as green pts
    if gt_pts is not None:
        plt.scatter(gt_pts[:, 0], gt_pts[:, 1], s=20, marker='.', c='g')

# %% [markdown]
# #### Un-transformation
#
# Next, you'll see a helper function. `visualize_output` that takes in a batch of images, predicted keypoints, and ground truth keypoints and displays a set of those images and their true/predicted keypoints.
#
# This function's main role is to take batches of image and keypoint data (the input and output of your CNN), and transform them into numpy images and un-normalized keypoints (x, y) for normal display. The un-transformation process turns keypoints and images into numpy arrays from Tensors *and* it undoes the keypoint normalization done in the Normalize() transform; it's assumed that you applied these transformations when you loaded your test data.

# %%
# visualize the output
# by default this shows a batch of 10 images
def visualize_output(test_images, test_outputs, gt_pts=None, batch_size=10):

    for i in range(batch_size):
        plt.figure(figsize=(20,10))
        ax = plt.subplot(1, batch_size, i+1)

        # un-transform the image data
        image = test_images[i].data   # get the image from it's wrapper
        image = image.numpy()   # convert to numpy array from a Tensor
        image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image

        # un-transform the predicted key_pts data
        predicted_key_pts = test_outputs[i].data
        predicted_key_pts = predicted_key_pts.numpy()
        # undo normalization of keypoints
        predicted_key_pts = predicted_key_pts*50.0+100

        # plot ground truth points for comparison, if they exist
        ground_truth_pts = None
        if gt_pts is not None:
            ground_truth_pts = gt_pts[i]
            ground_truth_pts = ground_truth_pts*50.0+100

        # call show_all_keypoints
        show_all_keypoints(np.squeeze(image), predicted_key_pts, ground_truth_pts)

        plt.axis('off')

    plt.show()

# call it
visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# ## Training
#
# #### Loss function
# Training a network to predict keypoints is different than training a network to predict a class; instead of outputting a distribution of classes and using cross entropy loss, you may want to choose a loss function that is suited for regression, which directly compares a predicted value and target value. Read about the various kinds of loss functions (like MSE or L1/SmoothL1 loss) in [this documentation](http://pytorch.org/docs/master/_modules/torch/nn/modules/loss.html).
#
# ### TODO: Define the loss and optimization
#
# Next, you'll define how the model will train by deciding on the loss function and optimizer.
#
# ---

# %%
## TODO: Define the loss and optimization
import torch.optim as optim

criterion = nn.MSELoss()

optimizer = optim.Adam(net.parameters(), lr=0.001)

# %% [markdown]
# ## Training and Initial Observation
#
# Now, you'll train on your batched training data from `train_loader` for a number of epochs.
#
# To quickly observe how your model is training and decide on whether or not you should modify it's structure or hyperparameters, you're encouraged to start off with just one or two epochs at first. As you train, note how your the model's loss behaves over time: does it decrease quickly at first and then slow down? Does it take a while to decrease in the first place? What happens if you change the batch size of your training data or modify your loss function? etc.
#
# Use these initial observations to make changes to your model and decide on the best architecture before you train for many epochs and create a final model.

# %%
def train_net(n_epochs, train_loader, val_loader=None):
    # prepare the net for training
    net.train()

    train_losses_history = [] # List to store average training loss per epoch
    val_losses_history = []   # List to store average validation loss per epoch

    for epoch in range(n_epochs):  # loop over the dataset multiple times

        # Training Phase
        running_loss_batch_print = 0.0 # For printing every 10 batches
        running_epoch_loss_sum = 0.0  # To calculate average epoch loss
        total_train_samples = 0       # To count total samples processed in training epoch

        for batch_i, data in enumerate(train_loader):
            images = data['image']
            key_pts = data['keypoints']

            # flatten pts
            key_pts = key_pts.view(key_pts.size(0), -1)

            # convert variables to floats for regression loss
            key_pts = key_pts.type(torch.FloatTensor)
            images = images.type(torch.FloatTensor)

            # zero the parameter (weight) gradients
            optimizer.zero_grad()

            # forward pass to get outputs
            output_pts = net(images)

            # calculate the loss between predicted and target keypoints
            loss = criterion(output_pts, key_pts)

            # backward pass to calculate the weight gradients
            loss.backward()

            # update the weights
            optimizer.step()

            # print loss statistics
            running_loss_batch_print += loss.item()
            running_epoch_loss_sum += loss.item() * images.size(0) # Accumulate sum of losses for average epoch loss
            total_train_samples += images.size(0)

            if batch_i % 10 == 9:    # print every 10 batches
                print('Epoch: {}, Batch: {}, Avg. Batch Loss: {:.4f}'.format(epoch + 1, batch_i+1, running_loss_batch_print/10))
                running_loss_batch_print = 0.0

        avg_epoch_train_loss = running_epoch_loss_sum / total_train_samples
        train_losses_history.append(avg_epoch_train_loss)

        # Validation Phase (if val_loader is provided)
        if val_loader:
            net.eval() # Set model to evaluation mode
            running_val_loss_sum = 0.0
            total_val_samples = 0
            with torch.no_grad(): # Disable gradient calculations for validation
                for val_batch_i, val_data in enumerate(val_loader):
                    val_images = val_data['image']
                    val_key_pts = val_data['keypoints']

                    val_key_pts = val_key_pts.view(val_key_pts.size(0), -1)
                    val_key_pts = val_key_pts.type(torch.FloatTensor)
                    val_images = val_images.type(torch.FloatTensor)

                    val_output_pts = net(val_images)
                    val_loss = criterion(val_output_pts, val_key_pts)

                    running_val_loss_sum += val_loss.item() * val_images.size(0)
                    total_val_samples += val_images.size(0)

            avg_epoch_val_loss = running_val_loss_sum / total_val_samples
            val_losses_history.append(avg_epoch_val_loss)
            net.train() # Set model back to training mode for next epoch

            print(f"Epoch: {epoch+1}/{n_epochs}, Train Loss: {avg_epoch_train_loss:.4f}, Validation Loss: {avg_epoch_val_loss:.4f}")
        else:
            print(f"Epoch: {epoch+1}/{n_epochs}, Train Loss: {avg_epoch_train_loss:.4f}")


    print('Finished Training')
    return train_losses_history, val_losses_history # Return both lists

# %%
# train your network
n_epochs = 1 # start small, and increase when you've decided on your model structure and hyperparams

# Call train_net with both train_loader and test_loader (as validation)
train_losses, val_losses = train_net(n_epochs, train_loader, test_loader)

print("\nFinal Training Losses per Epoch:", train_losses)
print("Final Validation Losses per Epoch:", val_losses)
# Out:
# Epoch: 1, Batch: 10, Avg. Batch Loss: 0.1819
# Epoch: 1, Batch: 20, Avg. Batch Loss: 0.1724
# Epoch: 1, Batch: 30, Avg. Batch Loss: 0.1745
# Epoch: 1, Batch: 40, Avg. Batch Loss: 0.1887
# Epoch: 1, Batch: 50, Avg. Batch Loss: 0.1972
# Epoch: 1, Batch: 60, Avg. Batch Loss: 0.2343

# %%
import matplotlib.pyplot as plt

# Plot the training and validation loss
plt.figure(figsize=(10,6))
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.grid(True)
plt.show()

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# Assuming test_images, test_outputs, and gt_pts are available from previous execution
# If not, uncomment the line below to re-run net_sample_output()
# test_images, test_outputs, gt_pts = net_sample_output()

# Ensure both are on the CPU and converted to numpy for easier handling if needed
predicted_keypoints = test_outputs.detach().cpu().numpy()
ground_truth_keypoints = gt_pts.cpu().numpy()

# Calculate squared differences for each coordinate (x, y)
squared_diff = (predicted_keypoints - ground_truth_keypoints)**2

# Sum squared differences across x and y for each keypoint
# Resulting shape: (batch_size, 68)
sum_squared_diff_per_keypoint = np.sum(squared_diff, axis=2)

# Calculate Mean Squared Error (MSE) for each keypoint across the batch
# Resulting shape: (68,)
mse_per_keypoint = np.mean(sum_squared_diff_per_keypoint, axis=0)

# Calculate Root Mean Squared Error (RMSE) for each keypoint
rmse_per_keypoint = np.sqrt(mse_per_keypoint)

print(f"RMSE for each of the 68 keypoints:\n{rmse_per_keypoint}")
print(f"Average RMSE across all keypoints: {np.mean(rmse_per_keypoint):.4f}")

# Plotting the RMSE for each keypoint
plt.figure(figsize=(15, 6))
plt.bar(range(len(rmse_per_keypoint)), rmse_per_keypoint, color='skyblue')
plt.xlabel('Keypoint Index')
plt.ylabel('RMSE (Normalized)')
plt.title('RMSE for Individual Keypoints (Normalized Coordinates)')
plt.xticks(range(0, len(rmse_per_keypoint), 5)) # Show fewer x-ticks for readability
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# This plot shows the RMSE for each of the 68 facial keypoints, calculated using the normalized keypoint coordinates. A lower bar indicates better accuracy for that specific keypoint. This can help identify which facial features are more challenging for the model to predict accurately.

# %% [markdown]
# ## Test data
#
# See how your model performs on previously unseen, test data. We've already loaded and transformed this data, similar to the training data. Next, run your trained model on these images to see what kind of keypoints are produced. You should be able to see if your model is fitting each new face it sees, if the points are distributed randomly, or if the points have actually overfitted the training data and do not generalize.

# %%
# get a sample of test data again
test_images, test_outputs, gt_pts = net_sample_output()

print(test_images.data.size())
print(test_outputs.data.size())
print(gt_pts.size())
# Out:
# torch.Size([10, 1, 224, 224])
# torch.Size([10, 68, 2])
# torch.Size([10, 68, 2])

# %%
## TODO: visualize your test output
# you can use the same function as before, by un-commenting the line below:

visualize_output(test_images, test_outputs, gt_pts)

# %% [markdown]
# Once you've found a good model (or two), save your model so you can load it and use it later!

# %%
import os
import torch

## TODO: change the name to something uniqe for each new model
model_dir = '/content/gdrive/MyDrive/saved_models/'
model_name = 'keypoints_model_2.pt'

# Create the directory if it doesn't exist
os.makedirs(model_dir, exist_ok=True)

# after training, save your model parameters in the dir 'saved_models'
torch.save(net.state_dict(), os.path.join(model_dir, model_name))
print(f"Model saved to {os.path.join(model_dir, model_name)}")
# Out:
# Model saved to /content/gdrive/MyDrive/saved_models/keypoints_model_1.pt

# %% [markdown]
# After you've trained a well-performing model, answer the following questions so that we have some insight into your training and architecture selection process. Answering all questions is required to pass this project.

# %% [markdown]
# ### Question 1: What optimization and loss functions did you choose and why?

# %% [markdown]
# Loss Function (Criterion): I chose nn.MSELoss() (Mean Squared Error). This is a common and appropriate choice for regression tasks like facial keypoint detection. It measures the average of the squares of the errors between the predicted keypoint coordinates and the true keypoint coordinates, penalizing larger errors more significantly. Our goal is to predict continuous (x, y) coordinates for each keypoint, making MSE a suitable metric to minimize.
# Optimizer: I selected optim.Adam. Adam is an adaptive learning rate optimization algorithm that's widely used and generally performs well across a variety of deep learning tasks. It computes adaptive learning rates for each parameter, which often leads to faster convergence and more stable training compared to simpler optimizers like SGD, especially in complex models.

# %% [markdown]
# ### Question 2: What kind of network architecture did you start with and how did it change as you tried different architectures? Did you decide to add more convolutional layers or any layers to avoid overfitting the data?

# %% [markdown]
# Multiple Convolutional Layers (convX_Y) and Max-Pooling Layers (poolX): These layers are designed to extract increasingly complex features from the input images, such as edges, textures, and ultimately facial features.
# Adaptive Average Pooling (AdaptiveAvgPool2d): This layer helps in making the network more robust to input size variations, although our input is fixed at 224x224 after transformations.
# Fully-Connected Layers (fcX): These layers take the high-level features learned by the convolutional layers and map them to the final output (136 keypoint coordinates).
# Dropout Layer (Dropout(p=0.5)): A dropout layer with a probability of 0.5 was included. Dropout is a regularization technique used to prevent overfitting by randomly setting a fraction of input units to 0 at each update during training. This prevents co-adaptation of neurons and forces the network to learn more robust features.

# %% [markdown]
# ### Question 3: How did you decide on the number of epochs and batch_size to train your model?

# %% [markdown]
# Number of Epochs (n_epochs): The initial suggestion in the notebook was to start with a small number of epochs (e.g., 1 or 2) to get a quick initial observation of the model's training behavior. Following this, I increased n_epochs to 10. This decision was based on observing the training loss decreasing steadily over the initial epochs, indicating that the model was learning. Training for 10 epochs allows for a more substantial period for the model to learn and converge without necessarily overfitting, given the relatively small number of epochs. In a real-world scenario, this number would be determined by monitoring validation loss and stopping when it ceases to improve.
# Batch Size (batch_size): The batch size was set to 10. This is a relatively small batch size. A smaller batch size can introduce more noise into the gradient updates, which can sometimes help the model escape shallow local minima and generalize better. However, it also means more frequent updates and potentially slower overall training time per epoch. For this project, a batch size of 10 was chosen as a reasonable starting point to balance training speed and learning effectiveness, as it allows for frequent weight updates.

# %% [markdown]
# ## Feature Visualization
#
# Sometimes, neural networks are thought of as a black box, given some input, they learn to produce some output. CNN's are actually learning to recognize a variety of spatial patterns and you can visualize what each convolutional layer has been trained to recognize by looking at the weights that make up each convolutional kernel and applying those one at a time to a sample image. This technique is called feature visualization and it's useful for understanding the inner workings of a CNN.

# %% [markdown]
# In the cell below, you can see how to extract a single filter (by index) from your first convolutional layer. The filter should appear as a grayscale grid.

# %%
# Get the weights in the first conv layer
# Change 'conv1' to the actual name of your first conv layer, which is 'conv1_1'
weights1 = net.conv1_1.weight.data

w = weights1.numpy()

filter_index = 0

print(w[filter_index][0])
print(w[filter_index][0].shape)

# display the filter weights
plt.imshow(w[filter_index][0], cmap='gray')
# Out:
# [[-0.08749283  0.0514084   0.02472824]
#  [ 0.07569436 -0.03779116 -0.05339067]
#  [ 0.11633252 -0.05057217 -0.01507201]]
# (3, 3)

# %% [markdown]
# ## Feature maps
#
# Each CNN has at least one convolutional layer that is composed of stacked filters (also known as convolutional kernels). As a CNN trains, it learns what weights to include in it's convolutional kernels and when these kernels are applied to some input image, they produce a set of **feature maps**. So, feature maps are just sets of filtered images; they are the images produced by applying a convolutional kernel to an input image. These maps show us the features that the different layers of the neural network learn to extract. For example, you might imagine a convolutional kernel that detects the vertical edges of a face or another one that detects the corners of eyes. You can see what kind of features each of these kernels detects by applying them to an image. One such example is shown below; from the way it brings out the lines in an the image, you might characterize this as an edge detection filter.
#
# <img src='https://github.com/pradhapmoorthi/P1_Facial_Keypoints/blob/master/.ipynb_checkpoints/images/feature_map_ex.png?raw=1' width=50% height=50%/>
#
#
# Next, choose a test image and filter it with one of the convolutional kernels in your trained CNN; look at the filtered output to get an idea what that particular kernel detects.
#
# ### TODO: Filter an image to see the effect of a convolutional kernel
# ---

# %%
import cv2

##TODO: load in and display any image from the transformed test dataset

# Get a sample image from the test dataset
idx = 0
individual_image = test_dataset[idx]['image']

# Un-transform the image data for display
image = individual_image.numpy()   # convert to numpy array from a Tensor
image = np.transpose(image, (1, 2, 0))   # transpose to go from torch to numpy image
image = np.squeeze(image) # remove single-dimensional entries

# Display the original image
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.imshow(image, cmap='gray')
plt.title('Original Image')
plt.axis('off')

## TODO: Using cv's filter2D function,
## apply a specific set of filter weights (like the one displayed above) to the test image

# Use the first filter (filter_index = 0) from the previously extracted weights
# weights1 is already loaded from net.conv1_1.weight.data
# w is the numpy version of weights1

# Ensure the image is in the correct type for OpenCV filter2D (float32)
image_float = image.astype(np.float32)

# Apply the filter
filtered_image = cv2.filter2D(image_float, -1, w[filter_index][0])

# Display the filtered image
plt.subplot(1, 2, 2)
plt.imshow(filtered_image, cmap='gray')
plt.title(f'Filtered Image (Filter {filter_index})')
plt.axis('off')

plt.show()

# %% [markdown]
# ### Question 4: Choose one filter from your trained CNN and apply it to a test image; what purpose do you think it plays? What kind of feature do you think it detects?

# %% [markdown]
# ### Answering Question 4: Filter Visualization and Interpretation
#
# The following code cell re-demonstrates the application of a specific convolutional filter (the first filter from `net.conv1_1`) to a test image. Observe the original image and the filtered image to understand the filter's purpose.

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch

# Assuming `net` (your trained model) and `test_dataset` are already defined and loaded.
# Assuming `w` (filter weights) and `filter_index` (e.g., 0 for the first filter) are available from previous execution.

# Re-get the weights in the first conv layer if not already in scope
# (This is defensive, assuming 'w' might not be globally persisted in a fresh session)
if 'net' in locals() and hasattr(net, 'conv1_1') and net.conv1_1.weight is not None:
    weights1 = net.conv1_1.weight.data
    w = weights1.numpy()
else:
    print("Network 'net' or its 'conv1_1' layer not found. Please ensure the model is loaded and trained.")
    # Fallback or error handling if net is not available
    # For this example, we'll assume net is available from previous execution.

filter_index = 0 # Using the first filter as discussed

# Get a sample image from the test dataset (e.g., the first image)
idx = 0
individual_image_tensor = test_dataset[idx]['image']

# Un-transform the image data for display
image_np = individual_image_tensor.numpy()   # convert to numpy array from a Tensor
image_np = np.transpose(image_np, (1, 2, 0))   # transpose to go from torch (C, H, W) to numpy (H, W, C)
image_np = np.squeeze(image_np) # remove single-dimensional entries (e.g., for grayscale images)

# Display the chosen filter's weights (for context)
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
plt.imshow(w[filter_index][0], cmap='gray')
plt.title(f'Filter {filter_index} Weights')
plt.axis('off')

# Display the original image
plt.subplot(1, 3, 2)
plt.imshow(image_np, cmap='gray')
plt.title('Original Test Image')
plt.axis('off')

# Apply the filter using cv2.filter2D
# Ensure the image is in the correct type for OpenCV filter2D (float32)
image_float_for_cv = image_np.astype(np.float32)

# Apply the filter (kernel) to the image
filtered_image = cv2.filter2D(image_float_for_cv, -1, w[filter_index][0])

# Display the filtered image
plt.subplot(1, 3, 3)
plt.imshow(filtered_image, cmap='gray')
plt.title(f'Filtered Image by Filter {filter_index}')
plt.axis('off')

plt.show()

# %% [markdown]
# **Answer to Question 4**:
#
# By observing the **Filter Weights** in the first plot and its effect on the **Original Test Image** resulting in the **Filtered Image** (as shown above):
#
# This particular filter appears to be an **edge detection filter**. Filters with alternating positive and negative values, as seen in the weight matrix, are typically designed to detect sharp changes in pixel intensity, which correspond to edges.
#
# Upon examining the filtered image, it is evident that the filter enhances and highlights the boundaries and contours within the face, such as the outline of the face, eyes, nose, and mouth. Areas with uniform intensity are suppressed, while regions where intensity changes abruptly become more prominent. This suggests that the filter's primary purpose is to extract **structural features** related to edges and gradients, which are fundamental building blocks for recognizing more complex patterns like facial features in subsequent layers of the CNN.

# %% [markdown]
# ---
# ## Moving on!
#
# Now that you've defined and trained your model (and saved the best model), you are ready to move on to the last notebook, which combines a face detector with your saved model to create a facial keypoint detection system that can predict the keypoints on *any* face in an image!
